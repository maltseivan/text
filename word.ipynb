# %%
 pip install natasha
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# 1. Токенизация по предложения
# 2. Токенизация по словам
# 3. Лематизация и стеминг текста
# 4. Стоп-слова
# 5. Чистка текста

# %%
import spacy
nlp = spacy.load('ru_core_news_md')
text = 'Посол Израиля на Украине Йоэль Лион признался, что пришел в шок, узнав о решении властей Львовской области объявить 2019 год годом лидера запрещенной в России Организации украинских националистов (ОУН) Степана Бандеры. Свое заявление он разместил в Twitter. «Я не могу понять, как прославление тех, кто непосредственно принимал участие в ужасных антисемитских преступлениях, помогает бороться с антисемитизмом и ксенофобией. Украина не должна забывать о преступлениях, совершенных против украинских евреев, и никоим образом не отмечать их через почитание их исполнителей», — написал дипломат. 11 декабря Львовский областной совет принял решение провозгласить 2019 год в регионе годом Степана Бандеры в связи с празднованием 110-летия со дня рождения лидера ОУН (Бандера родился 1 января 1909 года). В июле аналогичное решение принял Житомирский областной совет. В начале месяца с предложением к президенту страны Петру Порошенко вернуть Бандере звание Героя Украины обратились депутаты Верховной Рады. Парламентарии уверены, что признание Бандеры национальным героем поможет в борьбе с подрывной деятельностью против Украины в информационном поле, а также остановит «распространение мифов, созданных российской пропагандой». Степан Бандера (1909-1959) был одним из лидеров Организации украинских националистов, выступающей за создание независимого государства на территориях с украиноязычным населением. В 2010 году в период президентства Виктора Ющенко Бандера был посмертно признан Героем Украины, однако впоследствии это решение было отменено судом. '
doc = nlp(text)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# C:\Users\IVANMA~1\AppData\Local\Temp/ipykernel_10168/2755945197.py in <module>
# ----> 1 import spacy
#       2 nlp = spacy.load('ru_core_news_md')
# ...

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to C:\Users\Ivan
# [nltk_data]     Maltsev\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
doc = Doc(text)
doc.segment(segmenter)
doc.tag_morph(morph_tagger)
doc.parse_syntax(syntax_parser)

# %%
print(text)
# Out:
# Посол Израиля на Украине Йоэль Лион признался, что пришел в шок, узнав о решении властей Львовской области объявить 2019 год годом лидера запрещенной в России Организации украинских националистов (ОУН) Степана Бандеры. Свое заявление он разместил в Twitter. «Я не могу понять, как прославление тех, кто непосредственно принимал участие в ужасных антисемитских преступлениях, помогает бороться с антисемитизмом и ксенофобией. Украина не должна забывать о преступлениях, совершенных против украинских евреев, и никоим образом не отмечать их через почитание их исполнителей», — написал дипломат. 11 декабря Львовский областной совет принял решение провозгласить 2019 год в регионе годом Степана Бандеры в связи с празднованием 110-летия со дня рождения лидера ОУН (Бандера родился 1 января 1909 года). В июле аналогичное решение принял Житомирский областной совет. В начале месяца с предложением к президенту страны Петру Порошенко вернуть Бандере звание Героя Украины обратились депутаты Верховной Ра
# ...

# %%
pip install Doc
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
#   Created wheel for Doc: filename=doc-0.1.0-py3-none-any.whl size=1030 sha256=d0e228ea44ad2886f329250a56f2450e919d1ef92fa6635eab5d846c16061e1a
#   Stored in directory: c:\users\ivan maltsev\appdata\local\pip\cache\wheels\f6\08\f3\f558ce3fb1904722e9b3895e3d9e64d416d574d982d135a1d4
# Successfully built Doc
# ...

# %%
from sklearn.feature_extraction.text import CountVectorizer
bag_of_words = CountVectorizer().fit_transform(text)
bag_of_words.toarray()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\IVANMA~1\AppData\Local\Temp/ipykernel_10168/1682237956.py in <module>
#       1 from sklearn.feature_extraction.text import CountVectorizer
# ----> 2 bag_of_words = CountVectorizer().fit_transform(text)
#       3 bag_of_words.toarray()
#
# ~\anaconda3\lib\site-packages\sklearn\feature_extraction\text.py in fit_transform(self, raw_documents, y)
#    1190         # TfidfVectorizer.
#    1191         if isinstance(raw_documents, str):
# -> 1192             raise ValueError(
#    1193                 "Iterable over raw text documents expected, "
#    1194                 "string object received.")
#
# ValueError: Iterable over raw text documents expected, string object received.

# %%
from pprint import pprint
from razdel import tokenize
tokens = list(tokenize(text))
pprint(tokens)
# Out:
# [Substring(0, 5, 'Посол'),
#  Substring(6, 13, 'Израиля'),
#  Substring(14, 16, 'на'),
#  Substring(17, 24, 'Украине'),
#  Substring(25, 30, 'Йоэль'),
#  Substring(31, 35, 'Лион'),
#  Substring(36, 45, 'признался'),
#  Substring(45, 46, ','),
#  Substring(47, 50, 'что'),
#  Substring(51, 57, 'пришел'),
#  Substring(58, 59, 'в'),
#  Substring(60, 63, 'шок'),
#  Substring(63, 64, ','),
#  Substring(65, 70, 'узнав'),
#  Substring(71, 72, 'о'),
#  Substring(73, 80, 'решении'),
#  Substring(81, 88, 'властей'),
#  Substring(89, 98, 'Львовской'),
#  Substring(99, 106, 'области'),
#  Substring(107, 115, 'объявить'),
#  Substring(116, 120, '2019'),
#  Substring(121, 124, 'год'),
#  Substring(125, 130, 'годом'),
#  Substring(131, 137, 'лидера'),
#  Substring(138, 149, 'запрещенной'),
#  Substring(150, 151, 'в'),
#  Substring(152, 158, 'России'),
#  Substring(159, 170, 'Организации'),
#  Substring(171, 181, 'украинских'),
#  Substring(182, 195, 'националистов'),
#  Substring(196, 197, '('),
# ...

# %%
[_.text for _ in tokens]
# Out:
# ['Посол',
#  'Израиля',
#  'на',
#  'Украине',
#  'Йоэль',
#  'Лион',
#  'признался',
#  ',',
#  'что',
#  'пришел',
#  'в',
#  'шок',
#  ',',
#  'узнав',
#  'о',
#  'решении',
#  'властей',
#  'Львовской',
#  'области',
#  'объявить',
#  '2019',
#  'год',
#  'годом',
#  'лидера',
#  'запрещенной',
#  'в',
#  'России',
#  'Организации',
#  'украинских',
#  'националистов',
#  '(',
#  'ОУН',
#  ')',
#  'Степана',
#  'Бандеры',
#  '.',
#  'Свое',
#  'заявление',
#  'он',
#  'разместил',
#  'в',
#  'Twitter',
#  '.',
#  '«',
#  'Я',
#  'не',
#  'могу',
#  'понять',
#  ',',
#  'как',
#  'прославление',
#  'тех',
#  ',',
#  'кто',
#  'непосредственно',
#  'принимал',
#  'участие',
#  'в',
#  'ужасных',
#  'антисемитских',
#  'преступлениях',
#  ',',
#  'помогает',
#  'бороться',
#  'с',
#  'антисемитизмом',
#  'и',
#  'ксенофобией',
#  '.',
#  'Украина',
#  'не',
#  'должна',
#  'забывать',
#  'о',
#  'преступлениях',
#  ',',
#  'совершенных',
#  'против',
#  'украинских',
#  'евреев',
# ...

# %%
from sklearn.feature_extraction.text import CountVectorizer
bag_of_words = CountVectorizer().fit_transform(tokens)
bag_of_words.toarray()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\IVANMA~1\AppData\Local\Temp/ipykernel_10168/1338080091.py in <module>
#       1 from sklearn.feature_extraction.text import CountVectorizer
# ----> 2 bag_of_words = CountVectorizer().fit_transform(tokens)
#       3 bag_of_words.toarray()
#
# ~\anaconda3\lib\site-packages\sklearn\feature_extraction\text.py in fit_transform(self, raw_documents, y)
#    1200         max_features = self.max_features
#    1201
# -> 1202         vocabulary, X = self._count_vocab(raw_documents,
#    1203                                           self.fixed_vocabulary_)
#    1204
#
# ~\anaconda3\lib\site-packages\sklearn\feature_extraction\text.py in _count_vocab(self, raw_documents, fixed_vocab)
#    1112         for doc in raw_documents:
#    1113             feature_counter = {}
# -> 1114             for feature in analyze(doc):
# ...

# %%
import natasha
from natasha import (
    Segmenter,
    MorphVocab,
    
    NewsEmbedding,
    NewsMorphTagger,
    NewsSyntaxParser,
   
    PER,
    Doc
)

# %% [markdown]
# ### Библиотеки

# %%
import numpy as np
import pandas as pd
import sklearn
import plotly.express as px
from nltk.corpus import stopwords
from pymorphy2 import MorphAnalyzer
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer, HashingVectorizer
from tqdm import tqdm

# %% [markdown]
# ### Удаление спец. символов

# %%
import re
# фнкция для очистки текста
def delete_symbols(text: str):
#     удаление лишних пробелов
    text = re.sub(r'\s{2,}', ' ', text)
#     удаление всего, кроме букв
    clear_text = re.sub(r'[^А-Яа-я ]', '', text.lower())
    return clear_text

my_df['clear_text'] = my_df['text'].apply(lambda x: delete_symbols(x))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\IVANMA~1\AppData\Local\Temp/ipykernel_15164/1583783939.py in <module>
#       8     return clear_text
#       9
# ---> 10 text['clear_text'] = text['text'].apply(lambda x: delete_symbols(x))
#
# NameError: name 'text' is not defined

# %%
print(text)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\IVANMA~1\AppData\Local\Temp/ipykernel_15164/2214528614.py in <module>
# ----> 1 print(text)
#
# NameError: name 'text' is not defined

# %%
import re
# фнкция для очистки текста
def delete_symbols(text: str):
#     удаление лишних пробелов
    text = re.sub(r'\s{2,}', ' ', text)
#     удаление всего, кроме букв
    clear_text = re.sub(r'[^А-Яа-я ]', '', text.lower())
    return clear_text

my_df['clear_text'] = my_df['text'].apply(lambda x: delete_symbols(x))
